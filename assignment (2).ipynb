# %% [markdown]
# # "My Jupyter Notebook on IBM Watson Studio"

# %% [markdown]
# ### sethu S

# %% [markdown]
# #### No one can stop you!

# %% [markdown]
# ###### I'm really fond of Data Science because it facinates me a lot day by day its puzzling around the insights.

# %% [markdown]
# ###  Below  will execute multiplication tables for the given input

# %%
a=int(input("Enter the integer as input: "))
for i in range(1,11):
    print(f"{a} * {i} = {a*i}")
# Out:
# Enter the integer as input: 7
# 7 * 1 = 7
# 7 * 2 = 14
# 7 * 3 = 21
# 7 * 4 = 28
# 7 * 5 = 35
# 7 * 6 = 42
# 7 * 7 = 49
# 7 * 8 = 56
# 7 * 9 = 63
# 7 * 10 = 70

# %% [markdown]
# ##### It actually yields the simple multiplication table for the given input

# %% [markdown]
# ### output:

# %% [markdown]
#  - Enter the integer as input: 7
#  - 7 * 1 = 7
#  - 7 * 2 = 14
#  - 7 * 3 = 21
#  - 7 * 4 = 28
#  - 7 * 5 = 35
#  - 7 * 6 = 42
#  - 7 * 7 = 49
#  - 7 * 8 = 56
#  - 7 * 9 = 63
#  - 7 * 10 = 70

# %% [markdown]
# |Markdown||   less || pretty |
# |--------||--------||--------|
# | still  || renders|| nicely|
# |1||2||3|

# %% [markdown]
# www.IBM.com
